# %% [markdown]
# # Employee Attrition
# This Kaggle Competition is intended to create a model for predicting employee attrition with a binary classification. The evaluation metric for this competition is going to be the area under the ROC curve between the predicted probability and the observed target.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
# Load in the datasets
df_train0 = pd.read_csv('./Data/train.csv')
df_test0 = pd.read_csv('./Data/test.csv')

df = df_train0.copy()

# %% [markdown]
# ## Data Exploration

# %%
df.head()
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   int64
#  1   Age                       1677 non-null   int64
#  2   BusinessTravel            1677 non-null   object
#  3   DailyRate                 1677 non-null   int64
#  4   Department                1677 non-null   object
#  5   DistanceFromHome          1677 non-null   int64
#  6   Education                 1677 non-null   int64
#  7   EducationField            1677 non-null   object
#  8   EmployeeCount             1677 non-null   int64
#  9   EnvironmentSatisfaction   1677 non-null   int64
#  10  Gender                    1677 non-null   object
#  11  HourlyRate                1677 non-null   int64
#  12  JobInvolvement            1677 non-null   int64
#  13  JobLevel                  1677 non-null   int64
# ...

# %%
df.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1677.000000  1677.000000  1677.000000       1677.000000  1677.000000
# mean    838.000000    36.036971   892.749553          8.683959     2.937984
# std     484.252517     8.507112   374.496259          7.826143     1.039078
# min       0.000000    18.000000   107.000000          1.000000     1.000000
# 25%     419.000000    30.000000   589.000000          2.000000     2.000000
# 50%     838.000000    35.000000   890.000000          7.000000     3.000000
# 75%    1257.000000    41.000000  1223.000000         12.000000     4.000000
# max    1676.000000    60.000000  3921.000000         29.000000    15.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1677.0              1677.000000  1677.000000     1677.000000
# mean             1.0                 2.757901    67.798450        2.782349
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Initial impressions
# The initial examination of the data shows us that there are no missing values and no duplicated rows. There are 27 numeric columns and 8 categorical variables. Really 26 numerics since ID shouldn't count.
#
# Lets look for outliers

# %%
for field in df.select_dtypes(include=['int', 'float']):
    sns.boxplot(x=field, data=df)
    plt.title(f'Boxplot of {field}')
    plt.show()

# %%
for field in df.select_dtypes(exclude=['int', 'float']):
    sns.countplot(data=df, x=field)
    plt.title(f'Boxplot of {field}')
    plt.show()

# %%
sns.countplot(data=df, x='Attrition')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### Data manipulations
#
# EmployeeCount, StandardHours, and Over18 seem to all be the same values. We should exclude them from our analysis.
#
# Scaling: Apply a Standard Scaler to the numerical data
#
# Transformations: Drop EmployeeCount, StandardHours, and Over18
#
# Encodings: OneHotEncode the remaining categorical variables.

# %%
from sklearn.preprocessing import StandardScaler

def processing(df0):
    df = df0.copy()

    # Drop
    df.drop(columns=['EmployeeCount', 'StandardHours', 'Over18'], axis=1, inplace=True)

    # Scaling
    scaler = StandardScaler()
    
    # OneHot


    return df
